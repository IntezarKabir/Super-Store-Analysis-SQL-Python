# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display all columns
pd.set_option("display.max_columns", None)

# Better display
plt.style.use("ggplot")

# %%
df = sales = pd.read_csv("Sales.csv", encoding="latin1")
df1 = calendar = pd.read_csv("Calender.csv", encoding="latin1")

# %% [markdown]
# # First Five Rows

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0     1.0  CA-2013-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1     2.0  CA-2013-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2     3.0  CA-2013-138688  06-12-2016  06-12-2016    Second Class    DV-13045
# 3     4.0  US-2012-108966  10-11-2015  10-11-2015  Standard Class    SO-20335
# 4     5.0  US-2012-108966  10-11-2015  10-11-2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# # First Five Rows

# %%
df1.head()
# Out:
#          Date  Year  Quarter Quarter(Q) Quarter_&_Year  Month Month_Name  \
# 0  01-07-2016  2016        3         Q3      2016 - Q3      7        Jul
# 1  02-07-2016  2016        3         Q3      2016 - Q3      7        Jul
# 2  03-07-2016  2016        3         Q3      2016 - Q3      7        Jul
# 3  04-07-2016  2016        3         Q3      2016 - Q3      7        Jul
# 4  05-07-2016  2016        3         Q3      2016 - Q3      7        Jul
#
#   Month_&_Year  Week_of_Year Week_of_Year(W)  Day_of_Week  Day_Name
# 0       Jul-16            27         Week 27            5    Friday
# 1       Jul-16            27         Week 27            6  Saturday
# 2       Jul-16            27         Week 27            7    Sunday
# 3       Jul-16            28         Week 28            1    Monday
# 4       Jul-16            28         Week 28            2   Tuesday

# %% [markdown]
# # Last Five Rows

# %%
df.tail()
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 9990  9991.0  CA-2014-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9992.0  CA-2014-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9993.0  CA-2014-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9994.0  CA-2014-119914  05-04-2017  05-09-2017    Second Class
# 9994     NaN             NaN         NaN         NaN             NaN
#
#      Customer_ID Customer_Name   Segment        Country         City  \
# 9990    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa
# 9991    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster
# 9994         NaN           NaN       NaN            NaN          NaN
#
#            State  Postal_Code Region       Product_ID         Category  \
# ...

# %% [markdown]
# # Last Five Rows

# %%
df1.tail()
# Out:
#             Date  Year  Quarter Quarter(Q) Quarter_&_Year  Month Month_Name  \
# 1821  27-03-2018  2018        1         Q1      2018 - Q1      3        Mar
# 1822  28-03-2018  2018        1         Q1      2018 - Q1      3        Mar
# 1823  29-03-2018  2018        1         Q1      2018 - Q1      3        Mar
# 1824  30-03-2018  2018        1         Q1      2018 - Q1      3        Mar
# 1825  31-03-2018  2018        1         Q1      2018 - Q1      3        Mar
#
#      Month_&_Year  Week_of_Year Week_of_Year(W)  Day_of_Week   Day_Name
# 1821       Mar-18            13         Week 13            2    Tuesday
# 1822       Mar-18            13         Week 13            3  Wednesday
# 1823       Mar-18            13         Week 13            4   Thursday
# 1824       Mar-18            13         Week 13            5     Friday
# 1825       Mar-18            13         Week 13            6   Saturday

# %% [markdown]
# # Dataset Shape

# %%
print("Sales Shape :", sales.shape)
print("Calendar Shape :", calendar.shape)
# Out:
# Sales Shape : (9995, 27)
# Calendar Shape : (1826, 12)

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Discount_Status', 'Profit_Status', 'Is_Profitable', 'Sales_Per Unit',
#        'Retail_Sales_People', 'Returned'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Date', 'Year', 'Quarter', 'Quarter(Q)', 'Quarter_&_Year', 'Month',
#        'Month_Name', 'Month_&_Year', 'Week_of_Year', 'Week_of_Year(W)',
#        'Day_of_Week', 'Day_Name'],
#       dtype='object')

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9995 entries, 0 to 9994
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Row_ID               9994 non-null   float64
#  1   Order_ID             9994 non-null   object
#  2   Order_Date           9994 non-null   object
#  3   Ship_Date            9994 non-null   object
#  4   Ship_Mode            9994 non-null   object
#  5   Customer_ID          9994 non-null   object
#  6   Customer_Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Country              9994 non-null   object
#  9   City                 9994 non-null   object
#  10  State                9994 non-null   object
#  11  Postal_Code          9994 non-null   float64
#  12  Region               9994 non-null   object
#  13  Product_ID           9994 non-null   object
#  14  Category             9994 non-null   object
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1826 non-null   object
#  1   Year             1826 non-null   int64
#  2   Quarter          1826 non-null   int64
#  3   Quarter(Q)       1826 non-null   object
#  4   Quarter_&_Year   1826 non-null   object
#  5   Month            1826 non-null   int64
#  6   Month_Name       1826 non-null   object
#  7   Month_&_Year     1826 non-null   object
#  8   Week_of_Year     1826 non-null   int64
#  9   Week_of_Year(W)  1826 non-null   object
#  10  Day_of_Week      1826 non-null   int64
#  11  Day_Name         1826 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 171.3+ KB

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#             Row_ID   Postal_Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit  Sales_Per Unit
# count  9994.000000     9994.000000
# mean     28.656896       60.919569
# std     234.260108      142.927440
# min   -6599.978000        0.336000
# 25%       1.728750        5.470000
# 50%       8.666500       16.270000
# 75%      29.364000       63.940000
# ...

# %%
df1.describe()
# Out:
#               Year      Quarter        Month  Week_of_Year  Day_of_Week
# count  1826.000000  1826.000000  1826.000000   1826.000000  1826.000000
# mean   2016.000000     2.508762     6.523549     27.014239     4.001095
# std       1.414214     1.117326     3.449478     15.069985     2.000548
# min    2014.000000     1.000000     1.000000      1.000000     1.000000
# 25%    2015.000000     2.000000     4.000000     14.000000     2.000000
# 50%    2016.000000     3.000000     7.000000     27.000000     4.000000
# 75%    2017.000000     4.000000    10.000000     40.000000     6.000000
# max    2018.000000     4.000000    12.000000     53.000000     7.000000

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# Row_ID                 1
# Order_ID               1
# Order_Date             1
# Ship_Date              1
# Ship_Mode              1
# Customer_ID            1
# Customer_Name          1
# Segment                1
# Country                1
# City                   1
# State                  1
# Postal_Code            1
# Region                 1
# Product_ID             1
# Category               1
# Sub-Category           1
# Product_Name           1
# Sales                  1
# Quantity               1
# Discount               1
# Profit                 1
# Discount_Status        1
# Profit_Status          1
# Is_Profitable          1
# Sales_Per Unit         1
# Retail_Sales_People    1
# Returned               0
# dtype: int64

# %%
df["Customer_ID"].tail()
# Out:
# 9990    DB-13060
# 9991    DB-13060
# 9992    DB-13060
# 9993    CC-12220
# 9994         NaN
# Name: Customer_ID, dtype: object

# %% [markdown]
# # Values Add

# %%
df.fillna(0)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0        1.0  CA-2013-152156  11-08-2016  11-11-2016    Second Class
# 1        2.0  CA-2013-152156  11-08-2016  11-11-2016    Second Class
# 2        3.0  CA-2013-138688  06-12-2016  06-12-2016    Second Class
# 3        4.0  US-2012-108966  10-11-2015  10-11-2015  Standard Class
# 4        5.0  US-2012-108966  10-11-2015  10-11-2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9990  9991.0  CA-2014-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9992.0  CA-2014-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9993.0  CA-2014-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9994.0  CA-2014-119914  05-04-2017  05-09-2017    Second Class
# 9994     0.0               0           0           0               0
#
#      Customer_ID    Customer_Name    Segment        Country             City  \
# ...

# %%
df1.isnull().sum()
# Out:
# Date               0
# Year               0
# Quarter            0
# Quarter(Q)         0
# Quarter_&_Year     0
# Month              0
# Month_Name         0
# Month_&_Year       0
# Week_of_Year       0
# Week_of_Year(W)    0
# Day_of_Week        0
# Day_Name           0
# dtype: int64

# %% [markdown]
# # Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Convert Date Columns

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'], format= '%d-%m-%Y')
df1['Date'] = pd.to_datetime(df1['Date'], format= '%d-%m-%Y')

# %%
print(df['Order_Date'].dtype)
print(df['Ship_Date'].dtype)
print(df1['Date'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# # Merge Dataset

# %%
df = pd.merge(
    sales,
    calendar,
    left_on="Order_Date",
    right_on="Date",
    how="left"
)

# %% [markdown]
# # Final Check Dataset

# %%
df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0     1.0  CA-2013-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 1     2.0  CA-2013-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 2     3.0  CA-2013-138688 2016-12-06 2016-12-06    Second Class    DV-13045
# 3     4.0  US-2012-108966 2015-11-10 2015-11-10  Standard Class    SO-20335
# 4     5.0  US-2012-108966 2015-11-10 2015-11-10  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.shape
# Out:
# (9995, 39)

# %% [markdown]
# # Create New Columns

# %% [markdown]
# * Delivery Days

# %%
df["Delivery_Days"] = (
    df["Ship_Date"] - df["Order_Date"]
).dt.days

# %%
df['Delivery_Days'].head()
# Out:
# 0    92.0
# 1    92.0
# 2     0.0
# 3     0.0
# 4     0.0
# Name: Delivery_Days, dtype: float64

# %% [markdown]
# # Profit Margin

# %%
df["Profit_Margin"] = ((df["Profit"] / df["Sales"]) * 100).round(2)

# %% [markdown]
# # Result Show

# %%
df[["Sales", "Profit", "Profit_Margin"]].head()
# Out:
#       Sales    Profit  Profit_Margin
# 0  261.9600   41.9136          16.00
# 1  731.9400  219.5820          30.00
# 2   14.6200    6.8714          47.00
# 3  957.5775 -383.0310         -40.00
# 4   22.3680    2.5164          11.25

# %% [markdown]
# # Order Month

# %%
df["Order_Month"] = df["Order_Date"].dt.month_name()

# %% [markdown]
# * RESULT SHOW

# %%
df[['Order_Date', 'Order_Month']].head()
# Out:
#   Order_Date Order_Month
# 0 2016-08-11      August
# 1 2016-08-11      August
# 2 2016-12-06    December
# 3 2015-11-10    November
# 4 2015-11-10    November

# %% [markdown]
# # Order Year

# %%
df["Order_Year"] = df["Order_Date"].dt.year

# %% [markdown]
# * RESULT SHOW

# %%
df[['Order_Date', 'Order_Year']].head()
# Out:
#   Order_Date  Order_Year
# 0 2016-08-11      2016.0
# 1 2016-08-11      2016.0
# 2 2016-12-06      2016.0
# 3 2015-11-10      2015.0
# 4 2015-11-10      2015.0

# %% [markdown]
# # Order Quater

# %%
df["Order_Quarter"] = df["Order_Date"].dt.quarter

# %% [markdown]
# * RESULT SHOW

# %%
df[['Order_Date', 'Order_Quarter']].head()
# Out:
#   Order_Date  Order_Quarter
# 0 2016-08-11            3.0
# 1 2016-08-11            3.0
# 2 2016-12-06            4.0
# 3 2015-11-10            4.0
# 4 2015-11-10            4.0

# %% [markdown]
# # Final Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9995 entries, 0 to 9994
# Data columns (total 44 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Row_ID               9994 non-null   float64
#  1   Order_ID             9994 non-null   object
#  2   Order_Date           9994 non-null   datetime64[ns]
#  3   Ship_Date            9994 non-null   datetime64[ns]
#  4   Ship_Mode            9994 non-null   object
#  5   Customer_ID          9994 non-null   object
#  6   Customer_Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Country              9994 non-null   object
#  9   City                 9994 non-null   object
#  10  State                9994 non-null   object
#  11  Postal_Code          9994 non-null   float64
#  12  Region               9994 non-null   object
#  13  Product_ID           9994 non-null   object
#  14  Category             9994 non-null   object
# ...

# %% [markdown]
# # Save Clean Dataset

# %%
df.to_csv("Cleaned_Sales.csv", index=False)
